# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashchaure2006/Data_Science_Lab/blob/main/exp5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Experiment 05: Data Manipulation using Iris Dataset

import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()

# Convert to DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Add species column
df['species'] = iris.target

# Convert species numbers to names
df['species'] = df['species'].map({0:'setosa', 1:'versicolor', 2:'virginica'})

# Display first 5 rows
print("First 5 rows of dataset:")
print(df.head())

# MEAN
print("\nMean values:")
print(df.mean(numeric_only=True))

# MAX
print("\nMaximum values:")
print(df.max(numeric_only=True))

# MIN
print("\nMinimum values:")
print(df.min(numeric_only=True))

# SUM
print("\nSum of values:")
print(df.sum(numeric_only=True))

# COUNT
print("\nCount of values:")
print(df.count())

# Group by species and calculate mean
print("\nMean values grouped by species:")
print(df.groupby('species').mean())
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#
# Mean values:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64
#
# Maximum values:
# sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# dtype: float64
#
# Minimum values:
# sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# ...
